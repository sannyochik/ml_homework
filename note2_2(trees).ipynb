# %% [markdown]
# ### ***Теория классы***

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def say_name(self):
        print(self.name)


class Cat(Animal):
    def __init__(self):
        super().__init__("Кошка")

    def meow(self):
        print("Мяу!")


cat = Cat()
cat.say_name()
cat.meow()
# Out:
# Кошка
# Мяу!

# %% [markdown]
# инкапсуляция:

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def show_balance(self):
        print(f"Баланс: {self.balance}")


account = BankAccount("Аня", 1000)
account.deposit(500)
account.show_balance()
# Out:
# Баланс: 1500

# %% [markdown]
# наследование:

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def say_name(self):
        print(self.name)


class Cat(Animal):
    def meow(self):
        print("Мяу!")


cat = Cat("Кошка")
cat.say_name()
cat.meow()
# Out:
# Кошка
# Мяу!

# %% [markdown]
# полиморфизм:

# %%
class Animal:
    def make_sound(self):
        print("Какой-то звук")


class Cat(Animal):
    def make_sound(self):
        print("Мяу")


class Dog(Animal):
    def make_sound(self):
        print("Гав")


animals = [Cat(), Dog(), Animal()]

for animal in animals:
    animal.make_sound()
# Out:
# Мяу
# Гав
# Какой-то звук

# %%
class TD0:
    def operation(self, x, y):
        return x + y

    def run(self):
        x = int(input("Enter x > "))
        y = int(input("Enter y > "))
        z = self.operation(x, y)
        print("Result =", z)


class TD02(TD0):
    def operation(self, x, y):
        return x * y
    
obj1 = TD0()
obj1.run()

obj2 = TD02()
obj2.run()
# Out:
# Result = 8
# Result = 16

# %% [markdown]
# ### **Примеры**

# %% [markdown]
# Пример 1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Data:
    def __init__(self, *info):
        self.info = list(info)

    def __getitem__(self, i):
        return self.info[i]


class Teacher:
    def teach(self, info, *pupil):
        for i in pupil:
            i.take(info)


class Pupil:
    def __init__(self):
        self.knowledge = []

    def take(self, info):
        self.knowledge.append(info)


lesson = Data('class', 'object', 'inheritance', 'polymorphism', 'encapsulation')
marIvanna = Teacher()
vasy = Pupil()
pety = Pupil()

marIvanna.teach(lesson[2], vasy, pety)
marIvanna.teach(lesson[0], pety)

print(vasy.knowledge)
print(pety.knowledge)
# Out:
# ['inheritance']
# ['inheritance', 'class']

# %% [markdown]
# Пример 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random


class Warrior:
    def __init__(self, health):
        self.health = health

    def hit(self, target, target1):
        if target.health > 0:
            target.health -= 20
        if target1 == warrior1:
            target1 = "Warrior1"
        if target1 == warrior2:
            target1 = "Warrior2"
        print(target1, " has attacked")
        print(target.health, " left")
        if target.health == 0:
            print(target1, " has won")


warrior1 = Warrior(100)
warrior2 = Warrior(100)

q = int(input("Enter 1 to attack. Enter 2 to stop program:"))

while q != 2:
    if q == 1:
        j = random.randint(1, 3)
        if j % 2 == 0:
            warrior1.hit(warrior2, warrior1)
            q = int(input("Enter 1 to let some warrior attack:"))
        else:
            warrior2.hit(warrior1, warrior2)
            q = int(input("Enter 1 to let some warrior attack:"))
    else:
        print("Wrong input.")
        break
# Out:
# Warrior2  has attacked
# 80  left
# Warrior2  has attacked
# 60  left
# Warrior1  has attacked
# 80  left
# Warrior1  has attacked
# 60  left
# Warrior2  has attacked
# 40  left
# Warrior2  has attacked
# 20  left
# Warrior2  has attacked
# 0  left
# Warrior2  has won

# %% [markdown]
# Пример 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Rational:

    @staticmethod
    def gcd(a, b):
        while (b != 0):
            (a, b) = (b, a % b)
        return a

    @staticmethod
    def sgn(x):
        if x > 0:
            return 1
        elif x < 0:
            return -1
        else:
            return 0

    def __init__(self, n, d):
        if n == 0:
            self.num = 0
            self.den = 1
        else:
            z = self.sgn(n) * self.sgn(d)
            n = abs(n)
            d = abs(d)
            k = self.gcd(n, d)
            self.num = z * n // k
            self.den = d // k

    def __str__(self):
        if self.num == 0:
            return "0"
        else:
            return str(self.num) + "/" + str(self.den)

    def __add__(self, o):
        n1 = self.num
        d1 = self.den
        if type(o) == int:
            n2 = o
            d2 = 1
        else:
            n2 = o.num
            d2 = o.den
        n = n1 * d2 + n2 * d1
        d = d1 * d2
        return Rational(n, d)

    def __radd__(self, o):
        n1 = self.num
        d1 = self.den
        if type(o) == int:
            n2 = o
            d2 = 1
        else:
            n2 = o.num
            d2 = o.den
        n = n1 * d2 + n2 * d1
        d = d1 * d2
        return Rational(n, d)

    def __sub__(self, o):
        n1 = self.num
        d1 = self.den
        n2 = o.num
        d2 = o.den
        n = n1 * d2 - n2 * d1
        d = d1 * d2
        return Rational(n, d)

    def __mul__(self, o):
        n1 = self.num
        d1 = self.den
        n2 = o.num
        d2 = o.den
        n = n1 * n2
        d = d1 * d2
        return Rational(n, d)

    def __floordiv__(self, o):
        n1 = self.num
        d1 = self.den
        n2 = o.num
        d2 = o.den
        n = n1 * d2
        d = d1 * n2
        return Rational(n, d)


d1 = Rational(1, 2)
d2 = Rational(1, 3)
d3 = d1 + d2
print(d3)
d4 = d1 - d2
print(d4)
d5 = d1 * d2
print(d5)
d6 = d1 * d2
print(d6)
d7 = d1 // d2
print(d7)
d8 = 6 + d1
print(d8)
# Out:
# 5/6
# 1/6
# 1/6
# 1/6
# 3/2
# 13/2

# %% [markdown]
# ## Задание 1 ##

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import cos, sin, tan, asin, acos, atan, radians, pi

class TrigFunc:
    def __init__(self, angel):
        self.angel = angel
    def cosinus(self):
        return cos(self.angel)
    def sinus(self):
        return sin(self.angel)
    def tangens(self):
        return tan(self.angel)
    def arccos(self):
        return acos(self.angel)
    def arcsin(self):
        return asin(self.angel)
    def arctan(self):
        return atan(self.angel)
    def from_degrees_to_rad(self):
        return radians(self.angel)
    

obj1 = TrigFunc(pi/4)
print(obj1.sinus())
print(obj1.cosinus())
print(obj1.tangens())
print(obj1.arccos())
print(obj1.arcsin())
print(obj1.arctan())
print(obj1.from_degrees_to_rad())
# Out:
# 0.7071067811865476
# 0.7071067811865476
# 0.9999999999999999
# 0.6674572160283838
# 0.9033391107665127
# 0.6657737500283538
# 0.013707783890401887

# %% [markdown]
# ## ***Теория деревья***

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tree = [['a', 'b'], ['c'], ['d', ['e, f']]]
print(tree[0][1])
print(tree[2][1][0])
# Out:
# b
# e, f

# %% [markdown]
# ### *Примеры*

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Tree:
    def __init__(self, left, right):
        self.left = left
        self.right = right

t = Tree(Tree('a', 'b'), Tree('c', "d"))
t.right.left
# Out:
# 'c'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Tree:
    def __init__(self, kids, next=None):
        self.kids = self.val = kids
        self.next = next


t = Tree(Tree('a', Tree('b', Tree('c', Tree('d')))))
t.kids.next.next.val
# Out:
# 'c'

# %%
class Tree:
    def __init__(self, value=None, first_child=None, next_sibling=None):
        self.value = value
        self.first_child = first_child
        self.next_sibling = next_sibling


t = Tree(
    first_child=Tree(
        'a',
        next_sibling=Tree(
            'b',
            next_sibling=Tree(
                'c',
                next_sibling=Tree('d')
            )
        )
    )
)

print(t.first_child.next_sibling.next_sibling.value)
# Out:
# c

# %% [markdown]
# # **Задания**

# %% [markdown]
# задание 1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Tree:
    def __init__(self, left, right):
        self.left = left
        self.right = right
    

t = ['a', ['b', ['d', 'e']], ['c', ['f']]]

print(f'корень: {t[0]}')
print(f'левое поддерево: {t[1][0], t[1][1]}')
print(f'правое поддерево: {t[2][0], t[2][1]}')
# Out:
# корень: a
# левое поддерево: ('b', ['d', 'e'])
# правое поддерево: ('c', ['f'])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Tree:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

    def add_node(self, data):
        head = self

        while True:
            if data < head.data:
                if head.left is None:
                    head.left = Tree(data)
                    return
                head = head.left
            elif data > head.data:
                if head.right is None:
                    head.right = Tree(data)
                    return
                head = head.right
            else:
                return
    
    def print_tree(self):
        if self.left is not None:
            self.left.print_tree()  

        print(self.data)
        
        if self.right is not None:
            self.right.print_tree()

# %% [markdown]
# # **Деревья решений теория и примеры**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('sdfsf')
# Out:
# sdfsf

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import confusion_matrix, classification_report

# %%
dataset = sns.load_dataset('iris')
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dataset.shape
# Out:
# (150, 5)

# %%
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x_train, x_test, y_train, y_test = train_test_split(
    dataset.iloc[:, :-1],
    dataset.iloc[:, -1],
    test_size=0.2,
    # random_state=42
)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %%
x_train.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 73           6.1          2.8           4.7          1.2
# 85           6.0          3.4           4.5          1.6
# 58           6.6          2.9           4.6          1.3
# 15           5.7          4.4           1.5          0.4
# 68           6.2          2.2           4.5          1.5

# %%
y_train.head()
# Out:
# 73    versicolor
# 85    versicolor
# 58    versicolor
# 15        setosa
# 68    versicolor
# Name: species, dtype: str

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
classifier = DecisionTreeClassifier()
classifier.fit(x_train, y_train)

tree.plot_tree(classifier)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.75\ngini = 0.666\nsamples = 120\nvalue = [41, 38, 41]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.499\nsamples = 79\nvalue = [0, 38, 41]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.21\nsamples = 42\nvalue = [0, 37, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.054\nsamples = 36\nvalue = [0, 35, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 35\nvalue = [0, 35, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array(['virginica', 'setosa', 'versicolor', 'virginica', 'versicolor',
#        'setosa', 'versicolor', 'virginica', 'setosa', 'versicolor',
#        'virginica', 'setosa', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'versicolor', 'setosa', 'virginica', 'versicolor', 'virginica',
#        'versicolor', 'versicolor', 'setosa', 'versicolor', 'versicolor',
#        'versicolor', 'virginica', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 9  0  0]
#  [ 0 12  0]
#  [ 0  1  8]]
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         9
#   versicolor       0.92      1.00      0.96        12
#    virginica       1.00      0.89      0.94         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # **Задания**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
X = np.array([
    [-1, -1],
    [-2, -1],
    [-3, -2],
    [1, 1],
    [2, 1],
    [3, 2],
])

target = [0, 0, 0, 1, 1, 1]

x_train, x_test, y_train, y_test = train_test_split(
    X,
    target,
    random_state=42,
    test_size=0.2
)

# %%
classifier = DecisionTreeClassifier()
classifier.fit(x_train, y_train)

tree.plot_tree(classifier)
# Out:
# [Text(0.5, 0.75, 'x[1] <= -0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.625, 0.5, '  False')]

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array([0, 0])

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[2]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\alex0\OneDrive\Desktop\study\venv\Lib\site-packages\sklearn\metrics\_classification.py:620: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %% [markdown]
# # **Деревья решений для регрессии теория и примеры**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
from sklearn import tree
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
url = 'https://raw.githubusercontent.com/AnnaShestova/salary-years-simple-linear-regression/master/Salary_Data.csv'
df = pd.read_csv(url)

df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.figure(figsize=(7, 3))
plt.scatter(
    df['YearsExperience'],
    df['Salary'],
    colorizer='b',
    label='заработная плата'
)
plt.xlabel('Опыт(лет)')
plt.ylabel('заработная плата')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df.iloc[:, :-1],
    df.iloc[:, -1],
    test_size=0.2,
    random_state=42
)

# %%
regressor = DecisionTreeRegressor()
regressor.fit(x_train, y_train)
tree.plot_tree(regressor)
y_pred = regressor.predict(x_test)

# %%
dataframe = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
dataframe
# Out:
#       Actual  Predicted
# 27  112635.0   116969.0
# 15   67938.0    66029.0
# 23  113812.0   101302.0
# 17   83088.0    66029.0
# 8    64445.0    54445.0
# 9    57189.0    63218.0

# %%
print(f'mse: {mean_squared_error(y_test, y_pred)}')
print(f'mae: {mean_absolute_error(y_test, y_pred)}')
# Out:
# mse: 101047709.83333333
# mae: 8640.166666666666

# %%
mean_absolute_error(y_test, y_pred) / np.average(df.iloc[:, -1]) * 100
# Out:
# np.float64(11.368191606471674)

# %% [markdown]
# # **Задания**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
from sklearn import tree
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, root_mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv'

df = pd.read_csv(url)
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df.iloc[:, :-1],
    df.iloc[:, -1],
    test_size=0.2,
    random_state=42
)

regressor = DecisionTreeRegressor(
    max_depth=5, 
    random_state=42
)
regressor.fit(x_train, y_train)
tree.plot_tree(regressor)

y_pred = regressor.predict(x_test)
print(f'mae: {mean_absolute_error(y_test, y_pred)}')
print(f'mse: {mean_squared_error(y_test, y_pred)}')
print(f'rmse: {root_mean_squared_error(y_test, y_pred)}')
print(f'r_2: {r2_score(y_test, y_pred)}')
# Out:
# mae: 0.4963861466527857
# mse: 0.43350969496749786
# rmse: 0.6584145312548151
# r_2: 0.3366399264084673

# %%
plt.figure(figsize=(10, 5))
plt.scatter(
    df['alcohol'],
    df['quality'],
)
plt.xlabel('alcohol')
plt.ylabel('quality')
plt.show()
